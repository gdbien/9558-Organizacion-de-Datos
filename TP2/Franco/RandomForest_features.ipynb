# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %%
#Cargo los sets
X_train = pd.read_csv('data/X_train_features.csv', dtype={'id':'int',\
                                           'tipodepropiedad':'category',\
                                           'ciudad':'category', 'provincia':'category',\
                                           'antiguedad':'float', 'habitaciones':'float',\
                                           'garages':'float','banos':'float',\
                                           'metroscubiertos':'float', 'metrostotales':'float',\
                                           'idzona':'float',\
                                           'gimnasio':'bool', 'usosmultiples':'bool',\
                                           'piscina':'bool', 'escuelascercanas':'bool',\
                                           'centroscomercialescercanos':'bool'\
                                           }, index_col='id')
y_train = pd.read_csv('data/y_train.csv',header=None,squeeze=True,index_col=0)
X_test = pd.read_csv('data/X_test_features.csv', dtype={'id':'int',\
                                           'tipodepropiedad':'category',\
                                           'ciudad':'category', 'provincia':'category',\
                                           'antiguedad':'float', 'habitaciones':'float',\
                                           'garages':'float','banos':'float',\
                                           'metroscubiertos':'float', 'metrostotales':'float',\
                                           'idzona':'float',\
                                           'gimnasio':'bool', 'usosmultiples':'bool',\
                                           'piscina':'bool', 'escuelascercanas':'bool',\
                                           'centroscomercialescercanos':'bool'\
                                           }, index_col='id')
y_test = pd.read_csv('data/y_test.csv',header=None,squeeze=True,index_col=0)

# %%
X_submit = pd.read_csv('data/X_submit_features.csv', dtype={'id':'int',\
                                           'tipodepropiedad':'category',\
                                           'ciudad':'category', 'provincia':'category',\
                                           'antiguedad':'float', 'habitaciones':'float',\
                                           'garages':'float','banos':'float',\
                                           'metroscubiertos':'float', 'metrostotales':'float',\
                                           'idzona':'float',\
                                           'gimnasio':'bool', 'usosmultiples':'bool',\
                                           'piscina':'bool', 'escuelascercanas':'bool',\
                                           'centroscomercialescercanos':'bool'\
                                           }, index_col='id')

# %%
randomForest = RandomForestRegressor(n_estimators=1200, n_jobs= 5, oob_score=True, min_samples_leaf=2, max_features= 0.5)

# %%
y_train_log = np.log1p(y_train)
y_test_log = np.log1p(y_test)

# %%
# %time randomForest.fit(X_train, y_train_log)
# Out:
# CPU times: user 2h 51min 48s, sys: 2min 14s, total: 2h 54min 2s
# Wall time: 40min 49s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=0.5, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=2, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1200, n_jobs=5,
#            oob_score=True, random_state=None, verbose=0, warm_start=False)

# %%
def RMSE(actual, pred):
    return np.sqrt(mean_squared_error(actual, pred))

# %%
def print_score(r,train_set,test_set,train_target,test_target,F):
    res = [F(r.predict(train_set), train_target),
           F(r.predict(test_set), test_target),
           r.score(train_set, train_target), r.score(test_set, test_target)]
    if hasattr(r, 'oob_score_'): res.append(r.oob_score_)
    print(res)

# %%
# %time print_score(randomForest,X_train,X_test,y_train_log,y_test_log,RMSE)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-8-ce7d1483e55b> in print_score(r, train_set, test_set, train_target, test_target, F)
#       1 def print_score(r,train_set,test_set,train_target,test_target,F):
# ----> 2     res = [F(r.predict(train_set), train_target),
#       3            F(r.predict(test_set), test_target),
#       4            r.score(train_set, train_target), r.score(test_set, test_target)]
#       5     if hasattr(r, 'oob_score_'): res.append(r.oob_score_)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     686         check_is_fitted(self, 'estimators_')
#     687         # Check data
# --> 688         X = self._validate_X_predict(X)
#     689
#     690         # Assign chunk of trees to jobs
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
#     360                                  "call `fit` before exploiting the model.")
#     361
# --> 362         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     363
#     364     @property
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     375         """Validate X whenever one tries to predict, apply, predict_proba"""
#     376         if check_input:
# --> 377             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     378             if issparse(X) and (X.indices.dtype != np.intc or
#     379                                 X.indptr.dtype != np.intc):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1604
#    1605     def __array__(self, dtype=None):
# -> 1606         return com._values_from_object(self)
#    1607
#    1608     def __array_wrap__(self, result, context=None):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.values_from_object()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in get_values(self)
#    4686                [nan,  3.]])
#    4687         """
# -> 4688         return self.values
#    4689
#    4690     def get_dtype_counts(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in values(self)
#    4631         """
#    4632         self._consolidate_inplace()
# -> 4633         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    4634
#    4635     @property
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in as_array(self, transpose, items)
#    3947             arr = mgr.blocks[0].get_values()
#    3948         else:
# -> 3949             arr = mgr._interleave()
#    3950
#    3951         return arr.transpose() if transpose else arr
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in _interleave(self)
#    3976         for blk in self.blocks:
#    3977             rl = blk.mgr_locs
# -> 3978             result[rl.indexer] = blk.get_values(dtype)
#    3979             itemmask[rl.indexer] = 1
#    3980
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get_values(self, dtype)
#     217         """
#     218         if is_object_dtype(dtype):
# --> 219             return self.values.astype(object)
#     220         return self.values
#     221
#
# MemoryError:

# %%
features_importancia = pd.DataFrame(randomForest.feature_importances_,\
                                      index = X_train.columns,\
                                      columns=['importancia']).sort_values('importancia', ascending=False)\
                                      

features_importancia = features_importancia[features_importancia['importancia']>0]

# %%
features_importancia.head(50)
# Out:
#                                      importancia
# metroscubiertos                         0.345421
# banos                                   0.141588
# metrostotales                           0.098028
# provincia__Distrito Federal             0.088068
# idzona                                  0.041828
# garages                                 0.039175
# tipodepropiedad__Apartamento            0.027038
# tipodepropiedad__Terreno                0.021255
# habitaciones                            0.020363
# antiguedad                              0.019180
# año                                     0.017433
# dia                                     0.017047
# tipodepropiedad__Casa                   0.014051
# mes                                     0.013811
# provincia__Edo. de México               0.008031
# ciudad__Huixquilucan                    0.006082
# ciudad__San Pedro Garza García          0.004479
# ciudad__Benito Juárez                   0.003828
# ciudad__Naucalpan de Juárez             0.003804
# ciudad__Zapopan                         0.003257
# tipodepropiedad__Terreno comercial      0.003037
# centroscomercialescercanos              0.002706
# escuelascercanas                        0.002687
# provincia__Yucatán                      0.002510
# ciudad__Miguel Hidalgo                  0.002383
# piscina                                 0.002192
# provincia__Jalisco                      0.002176
# provincia__Nuevo León                   0.002165
# gimnasio                                0.002001
# tipodepropiedad__Casa en condominio     0.001991
# ciudad__Iztapalapa                      0.001872
# ciudad__Cuauhtémoc                      0.001583
# tipodepropiedad__Edificio               0.001531
# ciudad__San Andrés Cholula              0.001322
# ciudad__Mérida                          0.001301
# ciudad__Atizapán de Zaragoza            0.001227
# ciudad__Tlalnepantla de Baz             0.001129
# tipodepropiedad__Local Comercial        0.001099
# ciudad__Monterrey                       0.001050
# provincia__Querétaro                    0.001003
# provincia__San luis Potosí              0.000885
# ciudad__Tlalpan                         0.000844
# ciudad__San Luis Potosí                 0.000838
# ciudad__Guadalajara                     0.000828
# provincia__Coahuila                     0.000799
# tipodepropiedad__Bodega comercial       0.000782
# provincia__Puebla                       0.000752
# tipodepropiedad__Oficina comercial      0.000740
# provincia__Durango                      0.000730
# provincia__Sonora                       0.000700

# %%
features_50 = pd.read_csv('data/features_importancia_primera_etapa.csv',index_col=0).head(60)\
            .index.tolist()
features_50
# Out:
# ['metroscubiertos',
#  'metrostotales',
#  'banos',
#  'provincia__Distrito Federal',
#  'idzona',
#  'tipodepropiedad__Apartamento',
#  'garages',
#  'año',
#  'antiguedad',
#  'dia',
#  'ciudad__Huixquilucan',
#  'habitaciones',
#  'mes',
#  'ciudad__San Pedro Garza García',
#  'tipodepropiedad__Terreno',
#  'tipodepropiedad__Casa',
#  'ciudad__Miguel Hidalgo',
#  'provincia__Edo. de México',
#  'ciudad__Naucalpan de Juárez',
#  'ciudad__Zapopan',
#  'ciudad__Benito Juárez',
#  'ciudad__Cuauhtémoc',
#  'centroscomercialescercanos',
#  'escuelascercanas',
#  'tipodepropiedad__Terreno comercial',
#  'gimnasio',
#  'tipodepropiedad__Casa en condominio',
#  'tipodepropiedad__Edificio',
#  'piscina',
#  'ciudad__San Andrés Cholula',
#  'provincia__Jalisco',
#  'provincia__Yucatán',
#  'provincia__Nuevo León',
#  'ciudad__Atizapán de Zaragoza',
#  'ciudad__Alvaro Obregón',
#  'usosmultiples',
#  'ciudad__Mérida',
#  'ciudad__Iztapalapa',
#  'ciudad__Monterrey',
#  'ciudad__Tlalpan',
#  'ciudad__Coyoacán',
#  'tipodepropiedad__Bodega comercial',
#  'ciudad__Guadalajara',
#  'tipodepropiedad__Oficina comercial',
#  'tipodepropiedad__Local Comercial',
#  'provincia__San luis Potosí',
#  'provincia__Puebla',
#  'ciudad__La Magdalena Contreras',
#  'ciudad__San Luis Potosí',
#  'ciudad__Tlalnepantla de Baz',
#  'ciudad__Cuajimalpa de Morelos',
#  'provincia__Querétaro',
#  'ciudad__Querétaro',
#  'ciudad__San Miguel de Allende',
#  'ciudad__Azcapotzalco',
#  'tipodepropiedad__Rancho',
#  'ciudad__Santa Catarina',
#  'ciudad__Gustavo A. Madero',
#  'provincia__Morelos',
#  'ciudad__Cuernavaca']

# %%
features_importancia.head(50)
# Out:
#                                     importancia
# metroscubiertos                        0.298717
# metrostotales                          0.086350
# banos                                  0.085535
# provincia__Distrito Federal            0.056459
# idzona                                 0.033173
# tipodepropiedad__Apartamento           0.031338
# pro_ciu_tip_metroscubiertos_mean       0.030789
# año                                    0.027971
# antiguedad                             0.022567
# garages                                0.020929
# pro_ciu_tip_antiguedad_std             0.019446
# dia                                    0.018977
# pro_ciu_tip_garages_mean               0.018319
# pro_ciu_tip_banos_mean                 0.016836
# pro_ciu_tip_metroscubiertos_median     0.016532
# mes                                    0.016162
# pro_ciu_tip_habitaciones_mean          0.015750
# habitaciones                           0.010424
# pro_ciu_tip_antiguedad_mean            0.010363
# pro_ciu_tip_banos_std                  0.009104
# pro_ciu_tip_garages_std                0.008756
# pro_ciu_tip_metroscubiertos_std        0.008274
# ciudad__San Pedro Garza García         0.007394
# pro_ciu_tip_metrostotales_mean         0.007350
# pro_ciu_tip_antiguedad_sum             0.006971
# pro_ciu_tip_metroscubiertos_min        0.006714
# pro_ciu_tip_metrostotales_median       0.006336
# pro_ciu_tip_habitaciones_std           0.005634
# pro_ciu_tip_garages_sum                0.004835
# pro_ciu_tip_metrostotales_std          0.004797
# pro_ciu_tip_metroscubiertos_sum        0.004724
# pro_ciu_tip_metroscubiertos_max        0.004709
# ciudad__Huixquilucan                   0.004533
# tipodepropiedad__Casa                  0.004211
# tipodepropiedad__Terreno               0.004062
# pro_ciu_tip_metrostotales_min          0.004010
# pro_ciu_tip_banos_sum                  0.003995
# pro_ciu_tip_antiguedad_max             0.003783
# pro_ciu_tip_antiguedad_median          0.003650
# pro_ciu_tip_metrostotales_sum          0.003508
# centroscomercialescercanos             0.003045
# pro_ciu_tip_metrostotales_max          0.002969
# escuelascercanas                       0.002958
# pro_ciu_tip_habitaciones_median        0.002720
# pro_ciu_tip_habitaciones_sum           0.002482
# gimnasio                               0.002395
# pro_ciu_tip_habitaciones_max           0.002308
# piscina                                0.002262
# ciudad__Zapopan                        0.001953
# tipodepropiedad__Edificio              0.001805

# %%
features_importancia.to_csv('data/features_importancia_segunda_etapa.csv')

# %% [markdown]
# Voy a probar hacerlo con los primeros 50 features mas importantes

# %%
features_50 = pd.read_csv('data/features_importancia_segunda_etapa.csv',index_col=0).head(60)\
            .index.tolist()
features_50

# %%
X_train_50 = X_train[features_50]
X_test_50 = X_test[features_50]

# %%
# %time randomForest.fit(X_train_50, y_train_log)
# Out:
# CPU times: user 10min 49s, sys: 2.78 s, total: 10min 52s
# Wall time: 2min 34s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=0.5, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=2, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1200, n_jobs=5,
#            oob_score=True, random_state=None, verbose=0, warm_start=False)

# %%
# %time print_score(randomForest,X_train_50,X_test_50,y_train_log,y_test_log,RMSE)
# Out:
# [0.19162577269110856, 0.3659582438915469, 0.9475588728902499, 0.8102915629984416, 0.8308232660463724]
# CPU times: user 5min 40s, sys: 437 ms, total: 5min 40s
# Wall time: 1min 7s
